# %% [markdown]
# # Analysis of the **_results_**

# %% [markdown]
# ### **Setup**

# %%
# !git clone https://github.com/pante31/LLM_Creativity.git
# Out:
# Cloning into 'LLM_Creativity'...
# remote: Enumerating objects: 58, done.
# remote: Counting objects: 100% (58/58), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 58 (delta 13), reused 46 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (58/58), 1.04 MiB | 13.25 MiB/s, done.
# Resolving deltas: 100% (13/13), done.

# %%
import os
import json

# %% [markdown]
# ### Loading **results**

# %%
current_path = os.getcwd()
output_file = current_path + '/LLM_Creativity/creativity_metrics.json'

with open(output_file, 'r') as f:
    results = json.load(f)

# %%
metrics = list(results.keys())
metrics
# Out:
# ['perplexity', 'cr_pos', 'template_rate', 'template_per_token', 'llm_as_judge']

# %% [markdown]
# ## **_Creativity Index_**

# %%
creativity_index = results['creativity_index']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_48/3522679481.py in <cell line: 0>()
# ----> 1 creativity_index = results['creativity_index']
#
# KeyError: 'creativity_index'

# %% [markdown]
# ## **_Perplexity_**

# %%
perplexity = results['perplexity']
perplexity
# Out:
# [38.74918746948242,
#  18.037921905517578,
#  37.35714340209961,
#  17.28175926208496,
#  17.39276885986328,
#  28.310470581054688,
#  25.460834503173828,
#  27.963115692138672,
#  14.818737030029297,
#  35.449649810791016,
#  20.558326721191406,
#  30.870990753173828,
#  24.333030700683594,
#  25.35378074645996,
#  47.12760925292969,
#  24.946063995361328,
#  15.636770248413086,
#  19.4394588470459,
#  26.85540199279785,
#  31.316160202026367]

# %% [markdown]
# ## **_CR-POS_**

# %%
cr_pos = results['cr_pos']
cr_pos
# Out:
# [5.882,
#  5.539,
#  5.335,
#  5.899,
#  6.305,
#  5.109,
#  6.08,
#  5.02,
#  7.002,
#  5.924,
#  6.098,
#  5.914,
#  5.415,
#  5.922,
#  5.193,
#  5.063,
#  4.877,
#  6.245,
#  5.457,
#  6.603]

# %% [markdown]
# ## **_Template Rate_**

# %%
template_rate = results['template_rate']
template_rate
# Out:
# [0.47832817337461303,
#  0.44427244582043346,
#  0.3255395683453237,
#  0.20349761526232116,
#  0.4621676891615542,
#  0.48760330578512395,
#  0.5113636363636364,
#  0.34844192634560905,
#  0.5018925056775171,
#  0.42248062015503873,
#  0.459915611814346,
#  0.5375816993464052,
#  0.45857418111753373,
#  0.4437799043062201,
#  0.41774891774891776,
#  0.43478260869565216,
#  0.3140096618357488,
#  0.4652631578947368,
#  0.3649122807017544,
#  0.4891666666666667]

# %% [markdown]
# ## **_Tempalte-per-token_**

# %%
tempalte_per_token = results['template_per_token']
tempalte_per_token
# Out:
# [0.8544891640866873,
#  0.7925696594427245,
#  0.6115107913669064,
#  0.3688394276629571,
#  0.8466257668711656,
#  1.1129476584022038,
#  1.0511363636363635,
#  0.7705382436260623,
#  0.8841786525359576,
#  0.7906976744186046,
#  0.7510548523206751,
#  1.0065359477124183,
#  1.0096339113680155,
#  0.722488038277512,
#  0.9437229437229437,
#  0.9519450800915332,
#  0.6570048309178744,
#  0.6821052631578948,
#  0.6385964912280702,
#  0.8366666666666667]

# %% [markdown]
# ## **_LLM-as-a-judge_**

# %%
llm_as_a_judge = results['llm_as_judge']
llm_as_a_judge_metrics = ["surprise", "novelty", "value", "authenticity", "originality", "effectiveness", "fluency", "flexibility", "elaboration", "usefulness", "creativity"]
llm_as_a_judge_dictionary = {}

# %%
llm_as_a_judge_dictionary = {}
for j in range(len(llm_as_a_judge_metrics)):
    llm_as_a_judge_dictionary[metric] = [llm_as_a_judge[i*len(llm_as_a_judge_metrics)+j][llm_as_a_judge_metrics[j]] for i in range(len(llm_as_a_judge)//len(llm_as_a_judge_metrics))]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_48/1493123134.py in <cell line: 0>()
#       1 llm_as_a_judge_dictionary = {}
#       2 for j in range(len(llm_as_a_judge_metrics)):
# ----> 3     llm_as_a_judge_dictionary[metric] = [llm_as_a_judge[i*len(llm_as_a_judge_metrics)+j][llm_as_a_judge_metrics[j]] for i in range(len(llm_as_a_judge)//len(llm_as_a_judge_metrics))]
#
# /tmp/ipykernel_48/1493123134.py in <listcomp>(.0)
#       1 llm_as_a_judge_dictionary = {}
#       2 for j in range(len(llm_as_a_judge_metrics)):
# ----> 3     llm_as_a_judge_dictionary[metric] = [llm_as_a_judge[i*len(llm_as_a_judge_metrics)+j][llm_as_a_judge_metrics[j]] for i in range(len(llm_as_a_judge)//len(llm_as_a_judge_metrics))]
#
# KeyError: 'novelty'

# %%
llm_as_a_judge_dictionary
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_48/3103697848.py in <cell line: 0>()
# ----> 1 llm_as_a_judge_surprise = llm_as_a_judge['surprise']
#
# TypeError: list indices must be integers or slices, not str
