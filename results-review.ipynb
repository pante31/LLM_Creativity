# %% [markdown]
# # Analysis of the **_results_**

# %% [markdown]
# ### **Setup**

# %%
# !git clone https://github.com/pante31/LLM_Creativity.git
# Out:
# Cloning into 'LLM_Creativity'...
# remote: Enumerating objects: 66, done.
# remote: Counting objects: 100% (66/66), done.
# remote: Compressing objects: 100% (57/57), done.
# remote: Total 66 (delta 17), reused 51 (delta 9), pack-reused 0 (from 0)
# Receiving objects: 100% (66/66), 1.05 MiB | 4.29 MiB/s, done.
# Resolving deltas: 100% (17/17), done.

# %%
import os
import json
import pandas as pd

# %% [markdown]
# ### Loading **results**

# %%
current_path = os.getcwd()
output_file = current_path + '/LLM_Creativity/creativity_metrics.json'

with open(output_file, 'r') as f:
    results = json.load(f)

# %%
metrics = list(results.keys())
results_df = pd.DataFrame(columns=[metrics])
results_df.head()
# Out:
# Empty DataFrame
# Columns: [(creativity_index,), (perplexity,), (cr_pos,), (template_rate,), (template_per_token,), (llm_as_judge,)]
# Index: []

# %% [markdown]
# ## **_Creativity Index_**

# %%
creativity_index = results['creativity_index']
results_df.creativity_index = creativity_index
results_df.head(10)
# Out:
#   creativity_index perplexity cr_pos template_rate template_per_token  \
# 0         6.193798        NaN    NaN           NaN                NaN
# 1         6.353383        NaN    NaN           NaN                NaN
# 2         6.778182        NaN    NaN           NaN                NaN
# 3         5.734694        NaN    NaN           NaN                NaN
# 4         5.703476        NaN    NaN           NaN                NaN
# 5         6.744565        NaN    NaN           NaN                NaN
# 6         5.920341        NaN    NaN           NaN                NaN
# 7         5.884507        NaN    NaN           NaN                NaN
# 8         5.747521        NaN    NaN           NaN                NaN
# 9         6.995062        NaN    NaN           NaN                NaN
#
#   llm_as_judge
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN

# %% [markdown]
# ## **_Perplexity_**

# %%
perplexity = results['perplexity']
results_df.perplexity = perplexity
results_df.head(10)
# Out:
#   creativity_index perplexity cr_pos template_rate template_per_token  \
# 0         6.193798  38.749187    NaN           NaN                NaN
# 1         6.353383  18.037922    NaN           NaN                NaN
# 2         6.778182  37.357143    NaN           NaN                NaN
# 3         5.734694  17.281759    NaN           NaN                NaN
# 4         5.703476  17.392769    NaN           NaN                NaN
# 5         6.744565  28.310471    NaN           NaN                NaN
# 6         5.920341  25.460835    NaN           NaN                NaN
# 7         5.884507  27.963116    NaN           NaN                NaN
# 8         5.747521  14.818737    NaN           NaN                NaN
# 9         6.995062  35.449650    NaN           NaN                NaN
#
#   llm_as_judge
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN

# %% [markdown]
# ## **_CR-POS_**

# %%
cr_pos = results['cr_pos']
results_df.cr_pos = cr_pos
results_df.head(10)
# Out:
#   creativity_index perplexity cr_pos template_rate template_per_token  \
# 0         6.193798  38.749187  5.882           NaN                NaN
# 1         6.353383  18.037922  5.539           NaN                NaN
# 2         6.778182  37.357143  5.335           NaN                NaN
# 3         5.734694  17.281759  5.899           NaN                NaN
# 4         5.703476  17.392769  6.305           NaN                NaN
# 5         6.744565  28.310471  5.109           NaN                NaN
# 6         5.920341  25.460835  6.080           NaN                NaN
# 7         5.884507  27.963116  5.020           NaN                NaN
# 8         5.747521  14.818737  7.002           NaN                NaN
# 9         6.995062  35.449650  5.924           NaN                NaN
#
#   llm_as_judge
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN

# %% [markdown]
# ## **_Template Rate_**

# %%
template_rate = results['template_rate']
results_df.template_rate = template_rate
results_df.head(10)
# Out:
#   creativity_index perplexity cr_pos template_rate template_per_token  \
# 0         6.193798  38.749187  5.882      0.478328                NaN
# 1         6.353383  18.037922  5.539      0.444272                NaN
# 2         6.778182  37.357143  5.335      0.325540                NaN
# 3         5.734694  17.281759  5.899      0.203498                NaN
# 4         5.703476  17.392769  6.305      0.462168                NaN
# 5         6.744565  28.310471  5.109      0.487603                NaN
# 6         5.920341  25.460835  6.080      0.511364                NaN
# 7         5.884507  27.963116  5.020      0.348442                NaN
# 8         5.747521  14.818737  7.002      0.501893                NaN
# 9         6.995062  35.449650  5.924      0.422481                NaN
#
#   llm_as_judge
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN

# %% [markdown]
# ## **_Tempalte-per-token_**

# %%
template_per_token = results['template_per_token']
results_df.template_per_token = template_per_token
results_df.head(10)
# Out:
#   creativity_index perplexity cr_pos template_rate template_per_token  \
# 0         6.193798  38.749187  5.882      0.478328           0.854489
# 1         6.353383  18.037922  5.539      0.444272           0.792570
# 2         6.778182  37.357143  5.335      0.325540           0.611511
# 3         5.734694  17.281759  5.899      0.203498           0.368839
# 4         5.703476  17.392769  6.305      0.462168           0.846626
# 5         6.744565  28.310471  5.109      0.487603           1.112948
# 6         5.920341  25.460835  6.080      0.511364           1.051136
# 7         5.884507  27.963116  5.020      0.348442           0.770538
# 8         5.747521  14.818737  7.002      0.501893           0.884179
# 9         6.995062  35.449650  5.924      0.422481           0.790698
#
#   llm_as_judge
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN

# %% [markdown]
# ## **_LLM-as-a-judge_**

# %%
llm_as_a_judge = results['llm_as_judge']
llm_as_a_judge_metrics = ["surprise", "novelty", "value", "authenticity", "originality", "effectiveness", "fluency", "flexibility", "elaboration", "usefulness", "creativity"]
llm_as_a_judge_metrics_name = ["llm_" + llm_as_a_judge_metrics[i] for i in range(len(llm_as_a_judge_metrics))]

#results_df.drop("llm_as_judge", axis=1, inplace=True)

# %%
results_df.head()
# Out:
#   creativity_index perplexity cr_pos template_rate template_per_token  \
# 0         6.193798  38.749187  5.882      0.478328           0.854489
# 1         6.353383  18.037922  5.539      0.444272           0.792570
# 2         6.778182  37.357143  5.335      0.325540           0.611511
# 3         5.734694  17.281759  5.899      0.203498           0.368839
# 4         5.703476  17.392769  6.305      0.462168           0.846626
#
#   llm_surprise
# 0            5
# 1            5
# 2            5
# 3            5
# 4            5

# %%
llm_as_a_judge_dictionary = {}
for j in range(len(llm_as_a_judge_metrics)):
    print(j)
    llm_as_a_judge_dictionary[llm_as_a_judge_metrics[j]] = [llm_as_a_judge[i*len(llm_as_a_judge_metrics)+j][llm_as_a_judge_metrics[j]]['score'] for i in range(len(llm_as_a_judge)//len(llm_as_a_judge_metrics))]
    print(llm_as_a_judge_dictionary[llm_as_a_judge_metrics[j]])
    results_df[llm_as_a_judge_metrics_name[j]] = llm_as_a_judge_dictionary[llm_as_a_judge_metrics[j]]
# Out:
# 0
# [5, 5, 5, 5, 5, 4, 5, 4, 5, 5]
# 1
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_48/2138951844.py in <cell line: 0>()
#       2 for j in range(len(llm_as_a_judge_metrics)):
#       3     print(j)
# ----> 4     llm_as_a_judge_dictionary[llm_as_a_judge_metrics[j]] = [llm_as_a_judge[i*len(llm_as_a_judge_metrics)+j][llm_as_a_judge_metrics[j]]['score'] for i in range(len(llm_as_a_judge)//len(llm_as_a_judge_metrics))]
#       5     print(llm_as_a_judge_dictionary[llm_as_a_judge_metrics[j]])
#       6     results_df[llm_as_a_judge_metrics_name[j]] = llm_as_a_judge_dictionary[llm_as_a_judge_metrics[j]]
#
# /tmp/ipykernel_48/2138951844.py in <listcomp>(.0)
#       2 for j in range(len(llm_as_a_judge_metrics)):
#       3     print(j)
# ----> 4     llm_as_a_judge_dictionary[llm_as_a_judge_metrics[j]] = [llm_as_a_judge[i*len(llm_as_a_judge_metrics)+j][llm_as_a_judge_metrics[j]]['score'] for i in range(len(llm_as_a_judge)//len(llm_as_a_judge_metrics))]
#       5     print(llm_as_a_judge_dictionary[llm_as_a_judge_metrics[j]])
#       6     results_df[llm_as_a_judge_metrics_name[j]] = llm_as_a_judge_dictionary[llm_as_a_judge_metrics[j]]
#
# KeyError: 'novelty'

# %%
llm_as_a_judge[5*len(llm_as_a_judge_metrics)+1]
# Out:
# {'novelity': {'score': 3,
#   'justification': 'Ambiguous blend of familiar fantasy elements with slight original twists; lacks distinctiveness in core narrative.',
#   'excerpt': 'The Warrior stopped at the edge of the cloud bank, just as the sun had stopped there hours before.'}}
