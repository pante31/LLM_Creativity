# %% [markdown]
# # Analysis of the **_results_**

# %% [markdown]
# ### **Setup**

# %%
# !git clone https://github.com/pante31/LLM_Creativity.git
# Out:
# Cloning into 'LLM_Creativity'...
# remote: Enumerating objects: 92, done.
# remote: Counting objects: 100% (92/92), done.
# remote: Compressing objects: 100% (78/78), done.
# remote: Total 92 (delta 31), reused 63 (delta 14), pack-reused 0 (from 0)
# Receiving objects: 100% (92/92), 1.72 MiB | 6.92 MiB/s, done.
# Resolving deltas: 100% (31/31), done.

# %%
import os
import json
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Loading **results**

# %%
current_path = os.getcwd()
output_file = current_path + '/LLM_Creativity/creativity_metrics.json'

with open(output_file, 'r') as f:
    results = json.load(f)

# %%
metrics = list(results.keys())
results_df = pd.DataFrame(columns=metrics)
results_df.head()
# Out:
# Empty DataFrame
# Columns: [creativity_index, perplexity, cr_pos, template_rate, template_per_token, llm_as_a_judge]
# Index: []

# %% [markdown]
# ## **_Creativity Index_**

# %%
creativity_index = results['creativity_index']
results_df.creativity_index = creativity_index
results_df.head(10)
# Out:
#    creativity_index perplexity cr_pos template_rate template_per_token  \
# 0          6.193798        NaN    NaN           NaN                NaN
# 1          6.353383        NaN    NaN           NaN                NaN
# 2          6.778182        NaN    NaN           NaN                NaN
# 3          5.734694        NaN    NaN           NaN                NaN
# 4          5.703476        NaN    NaN           NaN                NaN
# 5          6.744565        NaN    NaN           NaN                NaN
# 6          5.920341        NaN    NaN           NaN                NaN
# 7          5.884507        NaN    NaN           NaN                NaN
# 8          5.747521        NaN    NaN           NaN                NaN
# 9          6.995062        NaN    NaN           NaN                NaN
#
#   llm_as_a_judge
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN

# %% [markdown]
# ## **_Perplexity_**

# %%
perplexity = results['perplexity']
results_df.perplexity = perplexity
results_df.head(10)
# Out:
#    creativity_index  perplexity cr_pos template_rate template_per_token  \
# 0          6.193798   23.689167    NaN           NaN                NaN
# 1          6.353383   11.709995    NaN           NaN                NaN
# 2          6.778182   19.537870    NaN           NaN                NaN
# 3          5.734694   10.454942    NaN           NaN                NaN
# 4          5.703476   10.589173    NaN           NaN                NaN
# 5          6.744565   18.217506    NaN           NaN                NaN
# 6          5.920341   16.838213    NaN           NaN                NaN
# 7          5.884507   16.877199    NaN           NaN                NaN
# 8          5.747521    9.272307    NaN           NaN                NaN
# 9          6.995062   17.537409    NaN           NaN                NaN
#
#   llm_as_a_judge
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN

# %% [markdown]
# ## **_CR-POS_**

# %%
cr_pos = results['cr_pos']
results_df.cr_pos = cr_pos
results_df.head(10)
# Out:
#    creativity_index  perplexity  cr_pos template_rate template_per_token  \
# 0          6.193798   23.689167   5.882           NaN                NaN
# 1          6.353383   11.709995   5.539           NaN                NaN
# 2          6.778182   19.537870   5.335           NaN                NaN
# 3          5.734694   10.454942   5.899           NaN                NaN
# 4          5.703476   10.589173   6.305           NaN                NaN
# 5          6.744565   18.217506   5.109           NaN                NaN
# 6          5.920341   16.838213   6.080           NaN                NaN
# 7          5.884507   16.877199   5.020           NaN                NaN
# 8          5.747521    9.272307   7.002           NaN                NaN
# 9          6.995062   17.537409   5.924           NaN                NaN
#
#   llm_as_a_judge
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN

# %% [markdown]
# ## **_Template Rate_**

# %%
template_rate = results['template_rate']
results_df.template_rate = template_rate
results_df.head(10)
# Out:
#    creativity_index  perplexity  cr_pos  template_rate template_per_token  \
# 0          6.193798   23.689167   5.882       0.478328                NaN
# 1          6.353383   11.709995   5.539       0.444272                NaN
# 2          6.778182   19.537870   5.335       0.325540                NaN
# 3          5.734694   10.454942   5.899       0.203498                NaN
# 4          5.703476   10.589173   6.305       0.462168                NaN
# 5          6.744565   18.217506   5.109       0.487603                NaN
# 6          5.920341   16.838213   6.080       0.511364                NaN
# 7          5.884507   16.877199   5.020       0.348442                NaN
# 8          5.747521    9.272307   7.002       0.501893                NaN
# 9          6.995062   17.537409   5.924       0.422481                NaN
#
#   llm_as_a_judge
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN

# %% [markdown]
# ## **_Tempalte-per-token_**

# %%
template_per_token = results['template_per_token']
results_df.template_per_token = template_per_token
results_df.head(10)
# Out:
#    creativity_index  perplexity  cr_pos  template_rate  template_per_token  \
# 0          6.193798   23.689167   5.882       0.478328            0.854489
# 1          6.353383   11.709995   5.539       0.444272            0.792570
# 2          6.778182   19.537870   5.335       0.325540            0.611511
# 3          5.734694   10.454942   5.899       0.203498            0.368839
# 4          5.703476   10.589173   6.305       0.462168            0.846626
# 5          6.744565   18.217506   5.109       0.487603            1.112948
# 6          5.920341   16.838213   6.080       0.511364            1.051136
# 7          5.884507   16.877199   5.020       0.348442            0.770538
# 8          5.747521    9.272307   7.002       0.501893            0.884179
# 9          6.995062   17.537409   5.924       0.422481            0.790698
#
#   llm_as_a_judge
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN

# %% [markdown]
# ## **_LLM-as-a-judge_**

# %%
llm_as_a_judge = results['llm_as_a_judge']
llm_as_a_judge_metrics = ["surprise", "novelty", "value", "authenticity", "originality", "effectiveness", "fluency", "flexibility", "elaboration", "usefulness", "creativity"]
llm_as_a_judge_metrics_name = ["llm_" + llm_as_a_judge_metrics[i] for i in range(len(llm_as_a_judge_metrics))]

results_df.drop("llm_as_a_judge", axis=1, inplace=True)

# %%
results_df.head()
# Out:
#    creativity_index  perplexity  cr_pos  template_rate  template_per_token
# 0          6.193798   23.689167   5.882       0.478328            0.854489
# 1          6.353383   11.709995   5.539       0.444272            0.792570
# 2          6.778182   19.537870   5.335       0.325540            0.611511
# 3          5.734694   10.454942   5.899       0.203498            0.368839
# 4          5.703476   10.589173   6.305       0.462168            0.846626

# %%
llm_as_a_judge_dictionary = {}
for j in range(len(llm_as_a_judge_metrics)):
    metric_list = []
    for i in range(len(llm_as_a_judge)//len(llm_as_a_judge_metrics)):
        try:
            metric_list.append(llm_as_a_judge[i*len(llm_as_a_judge_metrics)+j][llm_as_a_judge_metrics[j]]['score'])
        except TypeError:
            metric_list.append(-1)
    llm_as_a_judge_dictionary[llm_as_a_judge_metrics[j]] = metric_list
    results_df[llm_as_a_judge_metrics_name[j]] = llm_as_a_judge_dictionary[llm_as_a_judge_metrics[j]]

# %%
# TO BE REMOVED: Checking whether changning Likert-sc

output_file = current_path + '/LLM_Creativity/creativity_metrics_LLM.json'

with open(output_file, 'r') as f:
    results_LLM = json.load(f)

metrics_LLM = list(results_LLM.keys())
results_LLM_df = pd.DataFrame(columns=metrics_LLM)
llm_as_a_judge_LLM = results_LLM['llm_as_a_judge']
results_LLM_df.drop("llm_as_a_judge", axis=1, inplace=True)

llm_as_a_judge_dictionary = {}
for j in range(len(llm_as_a_judge_metrics)):
    metric_list = []
    for i in range(len(llm_as_a_judge_LLM)//len(llm_as_a_judge_metrics)):
        try:
            metric_list.append(llm_as_a_judge_LLM[i*len(llm_as_a_judge_metrics)+j][llm_as_a_judge_metrics[j]]['score'])
        except TypeError:
            metric_list.append(-1)
    llm_as_a_judge_dictionary[llm_as_a_judge_metrics[j]] = metric_list
    results_LLM_df[llm_as_a_judge_metrics_name[j]] = llm_as_a_judge_dictionary[llm_as_a_judge_metrics[j]]

# %%
# TO BE REMOVED: Checking whether changning Likert-scale the LLM evaluations change

LLM_rating_comparison = pd.concat([results_df[llm_as_a_judge_metrics_name], results_LLM_df], axis=1)
LLM_rating_comparison.head()
# Out:
#    llm_surprise  llm_novelty  llm_value  llm_authenticity  llm_originality  \
# 0             5            5          4                 3                5
# 1             5            5          4                 3                5
# 2             5            5          1                 1                5
# 3             5            5          5                 3                5
# 4             5            5          5                 5                5
#
#    llm_effectiveness  llm_fluency  llm_flexibility  llm_elaboration  \
# 0                  5            4                4                5
# 1                  4            5                2                5
# 2                  3            4                1                5
# 3                  4            5                2                5
# 4                  5            5                2                5
#
#    llm_usefulness  ...  llm_novelty  llm_value  llm_authenticity  \
# 0               4  ...           28         25                 8
# 1               4  ...           25          5                 8
# 2               1  ...           28          2                 8
# 3               4  ...           25          8                 8
# 4               4  ...           25         25                25
#
#    llm_originality  llm_effectiveness  llm_fluency  llm_flexibility  \
# 0               28                 12           25                8
# 1               25                 25           28                8
# 2               25                  8           25                1
# 3               28                 25           25                8
# 4               28                 25           28                8
#
#    llm_elaboration  llm_usefulness  llm_creativity
# 0               28               8              28
# 1               28              25              28
# 2               25               8              28
# 3               25               8              25
# 4               28              25              28
#
# [5 rows x 22 columns]

# %%
# TO BE REMOVED: Checking whether changning Likert-scale the LLM evaluations change

corr_LLM = LLM_rating_comparison.corr(method='pearson')

plt.figure(figsize=(15, 10))
sns.heatmap(corr_LLM, annot=True, cmap="coolwarm")
plt.show()

# %% [markdown]
# ### **LLM-as-a-judge**: ***Creativity***
#
# Evaluate the explainations for the ***creativity*** metric

# %%
creativity_list = [llm_as_a_judge[11*i+10] for i in range(len(llm_as_a_judge)//len(llm_as_a_judge_metrics))]
creativity_list[0:5]
# Out:
# [{'creativity': {'score': 5,
#    'justification': 'Unique narrative perspective',
#    'excerpt': 'I could feel my city, my current generation collapse'}},
#  {'creativity': {'score': 5,
#    'justification': 'Unique blend of sci-fi elements',
#    'excerpt': 'A giant... human face?!'}},
#  {'creativity': {'score': 5,
#    'justification': 'Unique narrative voice',
#    'excerpt': 'dark as it was with only a few lights'}},
#  {'creativity': {'score': 5,
#    'justification': 'Unique narrative structure',
#    'excerpt': 'She backed up and turned the other way'}},
#  {'creativity': {'score': 5,
#    'justification': 'Vivid, original storytelling',
#    'excerpt': 'a moment where noise seems to reach a crescendo'}}]

# %% [markdown]
# ## **<u>Results review:</u> _Correlation Matrix_**
#
# Method of correlation:
# - **pearson** : standard correlation coefficient
#     - It is correlation coefficient that measures **_linear correlation_** between two sets of data.
# - **spearman** : Spearman rank correlation
#     - It is a number ranging from -1 to 1 that indicates how strongly two sets of ranks are correlated. Used for **_non-linear correlations_**.
#
#
# > Do we need to **normalize data** before analyzing them?
# - **_Min-Max Normalization_(scaling between 0 and 1)** with `MinMaxScaler()`
#     - `df['normalized'] = (df['values'] - df['values'].min()) / (df['values'].max() - df['values'].min())`
# - **_Standardization_ (in case of outliers)** with `StandardScaler()`
#     - It transforms your data such that it has a _mean_ of **0** and a _standard deviation_ of **1**.

# %% [markdown]
# ### ***Pearson* correlation**

# %%
corr = results_df.corr(method='pearson')

plt.figure(figsize=(12, 10))
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.show()

# %% [markdown]
# ### ***Spearman* correlation**

# %%
corr = results_df.corr(method='spearman')

plt.figure(figsize=(12, 10))
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.show()

# %% [markdown]
# ## **<u>Results review:</u> _Factor Analysis_**

# %% [markdown]
# ### How many factors?
# <u>Determine the number of ***factors*** to keep:</u>
# - The **Kaiser criterion** states that you should use a number of factors equal to the <u>number of the **_eigenvalues_** of the correlation matrix that are greater than one</u>.
# - The “**Scree test**” states that you should plot the **_eigenvalues_** of the correlation matrix in descending order, and then use <u>a number of factors equal to the number of eigenvalues that occur prior to the last major drop in eigenvalue magnitude</u>.

# %%
eigenvalues, eigenvectors = np.linalg.eig(corr)
kaiser_criterion = sum(eigenvalues > 1)
print("Factors by Kaiser criterion:", kaiser_criterion)

eigenvalues
# Out:
# Factors by Kaiser criterion: 5
# array([3.81814315, 2.49664804, 1.90232828, 1.41743067, 1.05423305,
#        0.06479713, 0.86847447, 0.74601986, 0.72475273, 0.64783106,
#        0.24356785, 0.29551885, 0.32539071, 0.38441938, 0.47661051,
#        0.53383428])

# %%
plt.plot(range(1, len(eigenvalues)+1), sorted(eigenvalues, reverse=True), marker='o')
plt.xlabel('Factor Number')
plt.ylabel('Eigenvalue')
plt.title('Scree Plot')
plt.show()

# %%
from sklearn.datasets import load_iris
from sklearn.decomposition import PCA, FactorAnalysis
from sklearn.preprocessing import StandardScaler

data = results_df.copy()
X = StandardScaler().fit_transform(data)
feature_names = list(data.columns)

# %%
feature_names
# Out:
# ['creativity_index',
#  'perplexity',
#  'cr_pos',
#  'template_rate',
#  'template_per_token',
#  'llm_surprise',
#  'llm_novelty',
#  'llm_value',
#  'llm_authenticity',
#  'llm_originality',
#  'llm_effectiveness',
#  'llm_fluency',
#  'llm_flexibility',
#  'llm_elaboration',
#  'llm_usefulness',
#  'llm_creativity']

# %%
n_comps = 3

methods = [
    ("PCA", PCA()),
    ("Unrotated FA", FactorAnalysis()),
    ("Varimax FA", FactorAnalysis(rotation="varimax")),
]
fig, axes = plt.subplots(ncols=len(methods), figsize=(12, 8), sharey=True)

for ax, (method, fa) in zip(axes, methods):
    fa.set_params(n_components=n_comps)
    fa.fit(X)

    components = fa.components_.T
    print("\n\n %s :\n" % method)
    print(components)

    vmax = np.abs(components).max()
    ax.imshow(components, cmap="RdBu_r", vmax=vmax, vmin=-vmax)
    ax.set_yticks(np.arange(len(feature_names)))
    ax.set_yticklabels(feature_names)
    ax.set_title(str(method))
    ax.set_xticks(range(n_comps))
    ax.set_xticklabels([f"{i}" for i in range(1,n_comps+1)])
fig.suptitle("Factors")
plt.tight_layout()
plt.show()
# Out:
#  PCA :
#
# [[ 0.14735408  0.00387045 -0.34468496]
#  [ 0.17552992  0.29340668 -0.39374733]
#  [-0.24412709 -0.33211272  0.09033064]
#  [ 0.12082731  0.45946137 -0.03115164]
#  [ 0.21677308  0.51252254 -0.05435951]
#  [-0.02358153  0.12948033 -0.24269213]
#  [-0.24604018 -0.07246989 -0.42506013]
#  [-0.30620196  0.32300988  0.16136299]
#  [-0.20504803  0.26963253  0.07881128]
#  [-0.28113945  0.03963125 -0.34119356]
#  [-0.3044678   0.25534625  0.07359716]
#  [-0.26793701  0.10221772  0.13007374]
#  [-0.24918748  0.17866862  0.30700694]
#  [-0.28205992 -0.09852747 -0.19454564]
#  [-0.35809506  0.10491764  0.11175811]
#  [-0.34055461 -0.03002986 -0.39862963]]
#
#
#  Unrotated FA :
#
# [[ 0.05093871  0.06545133  0.26753187]
#  [ 0.45560482 -0.02826331  0.18796029]
#  [-0.65238172 -0.0891049  -0.16220734]
#  [ 0.80639965 -0.13611314 -0.07651745]
#  [ 0.99597326 -0.02811964  0.0031425 ]
#  [ 0.094417   -0.10619584  0.00974844]
#  [-0.20506037 -0.61463307  0.16228726]
#  [ 0.09566615 -0.34914508 -0.72850216]
#  [ 0.08828722 -0.28825564 -0.37510915]
#  [-0.17282359 -0.54413945 -0.04078406]
#  [ 0.08622374 -0.4049801  -0.55076418]
#  [-0.06672252 -0.23408016 -0.39344595]
#  [-0.10318503 -0.1573555  -0.56587199]
#  [-0.33619239 -0.48028229 -0.07947211]
#  [-0.16156088 -0.38512459 -0.55411126]
#  [-0.24249934 -0.92679405  0.13556029]]
#
#
#  Varimax FA :
#
# [[ 0.05661746 -0.00535376  0.27425851]
#  [ 0.46517279 -0.00942432  0.16501243]
#  [-0.64125365 -0.13930132 -0.17100212]
#  [ 0.81170073  0.01679131 -0.12458765]
#  [ 0.98818267  0.12589759 -0.02020182]
#  [ 0.10906538 -0.08878943 -0.02254633]
#  [-0.10502112 -0.65940858 -0.01765247]
#  [ 0.10186637 -0.11121949 -0.79938925]
#  [ 0.10655184 -0.15401158 -0.44330572]
#  [-0.0951675  -0.53058877 -0.19245203]
#  [ 0.11094831 -0.21552214 -0.64500021]
#  [-0.05542581 -0.12141747 -0.44297959]
#  [-0.11254126 -0.00589145 -0.58559267]
#  [-0.26798265 -0.48439101 -0.20871718]
#  [-0.13689087 -0.23394145 -0.63874443]
#  [-0.09884922 -0.95335477 -0.13218645]]

# %% [markdown]
# <u>There might be these **three factors** underlying the metrics:</u>
# 1. **_Text structure_**
# 2. **_LLM-judged creativity_**
# 3. **_LLM-judged quality_**

# %% [markdown]
# ## **<u>Results review:</u> _Plots_**

# %% [markdown]
# ### **_Scatter plots_**

# %%
sns.scatterplot(data=results_df, x="template_rate", y="template_per_token")
# Out:
# <Axes: xlabel='template_rate', ylabel='template_per_token'>
